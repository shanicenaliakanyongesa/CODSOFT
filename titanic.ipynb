# %%
import pandas
data=pandas.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
age=data['Age'].mean()
age
data['Age'].fillna(age, inplace=True)
# Out:
# C:\Users\Shanice\AppData\Local\Temp\ipykernel_5432\3693340316.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(age, inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data['Cabin'].fillna('Unknown', inplace=True)
data.isnull().sum()
# Out:
# C:\Users\Shanice\AppData\Local\Temp\ipykernel_5432\2287125231.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Cabin'].fillna('Unknown', inplace=True)
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Replacing
data['Survived'].replace({0:'Not Survived',
                        1:'Survived'},
                         inplace = True)

data['Pclass'].replace({1:'First class',
                              2:'Second class',
                              3:'Third class'
                              },
                              inplace = True)


data['Embarked'].replace({'C':'Cherbourg',
                             'Q': 'Queenstown',
                              'S': 'Southampton'
                              },
                              inplace = True)
# Out:
# C:\Users\Shanice\AppData\Local\Temp\ipykernel_5432\3282948204.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Survived'].replace({0:'Not Survived',
# C:\Users\Shanice\AppData\Local\Temp\ipykernel_5432\3282948204.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.head(20)
# Out:
#     PassengerId      Survived        Pclass  \
# 0             1  Not Survived   Third class
# 1             2      Survived   First class
# 2             3      Survived   Third class
# 3             4      Survived   First class
# 4             5  Not Survived   Third class
# 5             6  Not Survived   Third class
# 6             7  Not Survived   First class
# 7             8  Not Survived   Third class
# 8             9      Survived   Third class
# 9            10      Survived  Second class
# 10           11      Survived   Third class
# 11           12      Survived   First class
# 12           13  Not Survived   Third class
# 13           14  Not Survived   Third class
# 14           15  Not Survived   Third class
# 15           16      Survived  Second class
# 16           17  Not Survived   Third class
# 17           18      Survived  Second class
# 18           19  Not Survived   Third class
# 19           20      Survived   Third class
#
# ...

# %%
data.groupby(['Sex','Survived','Pclass']).size()
# Out:
# Sex     Survived      Pclass
# female  Not Survived  First class       3
#                       Second class      6
#                       Third class      72
#         Survived      First class      89
#                       Second class     70
#                       Third class      72
# male    Not Survived  First class      77
#                       Second class     91
#                       Third class     300
#         Survived      First class      45
#                       Second class     17
#                       Third class      47
# dtype: int64

# %%
data.groupby('Pclass').size()
# Out:
# Pclass
# First class     214
# Second class    184
# Third class     491
# dtype: int64

# %%
data['Fare'].mean()
# Out:
# 32.09668087739032

# %%
#pichart
import matplotlib.pyplot as plt
import seaborn as sns
data.groupby('Sex').size().plot(kind='pie',autopct='% 1.1f%%')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    object
#  2   Pclass       889 non-null    object
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Cabin        889 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 90.3+ KB

# %%
data.nlargest(3, 'Age')
# Out:
#      PassengerId      Survived       Pclass  \
# 630          631      Survived  First class
# 851          852  Not Survived  Third class
# 96            97  Not Survived  First class
#
#                                      Name   Sex   Age  SibSp  Parch    Ticket  \
# 630  Barkworth, Mr. Algernon Henry Wilson  male  80.0      0      0     27042
# 851                   Svensson, Mr. Johan  male  74.0      0      0    347060
# 96              Goldschmidt, Mr. George B  male  71.0      0      0  PC 17754
#
#         Fare    Cabin     Embarked
# 630  30.0000      A23  Southampton
# 851   7.7750  Unknown  Southampton
# 96   34.6542       A5    Cherbourg

# %%
data.sort_values('Age', ascending=True)
# Out:
#      PassengerId      Survived        Pclass  \
# 803          804      Survived   Third class
# 755          756      Survived  Second class
# 469          470      Survived   Third class
# 644          645      Survived   Third class
# 831          832      Survived  Second class
# ..           ...           ...           ...
# 116          117  Not Survived   Third class
# 493          494  Not Survived   First class
# 96            97  Not Survived   First class
# 851          852  Not Survived   Third class
# 630          631      Survived   First class
#
#                                      Name     Sex    Age  SibSp  Parch  \
# 803       Thomas, Master. Assad Alexander    male   0.42      0      1
# 755             Hamalainen, Master. Viljo    male   0.67      1      1
# 469         Baclini, Miss. Helene Barbara  female   0.75      2      1
# 644                Baclini, Miss. Eugenie  female   0.75      2      1
# ...

# %%
# Box
# Check for outliers
sns.boxplot(y = 'Age', data = data, x = 'Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()
data['Sex']=encoder.fit_transform(data['Sex'])
data['Embarked']=encoder.fit_transform(data['Embarked'])
data['Ticket']=encoder.fit_transform(data['Ticket'])
data['Fare']=encoder.fit_transform(data['Fare'])
data['Cabin']=encoder.fit_transform(data['Cabin'])

data
# Out:
#      PassengerId      Survived        Pclass  \
# 0              1  Not Survived   Third class
# 1              2      Survived   First class
# 2              3      Survived   Third class
# 3              4      Survived   First class
# 4              5  Not Survived   Third class
# ..           ...           ...           ...
# 886          887  Not Survived  Second class
# 887          888      Survived   First class
# 888          889  Not Survived   Third class
# 889          890      Survived   First class
# 890          891  Not Survived   Third class
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# ...

# %%
array=data.values
x=array[:, 4:11]
y=array[:,1]

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y, test_size=0.3, random_state=42)

# %%
# Imports Classification Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

# Create an Empty List and append all models, Give the Models an alias Name
# i.e we called KNeighborsClassifier() alias KNC etc
models = []
models.append(('D Trees', DecisionTreeClassifier()))
models.append(('Gaussian', GaussianNB()))
models.append(('KNC', KNeighborsClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('Gradient Boosting', GradientBoostingClassifier()))
models.append(('Linear Disc', LinearDiscriminantAnalysis()))
models.append(('Support Machines', SVC(gamma = 'auto')))

# Import Cross Validation and KFOLD
from sklearn.model_selection import cross_val_score, KFold
# Create a for loop so that each model is tested in turn
for name, model in models:
     # Here we do a 10 split K-FOLD
     kfold = KFold(n_splits = 10, random_state=42, shuffle=True)

     # We get the results for each Fold
     cv_results = cross_val_score(model, x_train, y_train, cv = kfold,
     scoring='accuracy')

     # Get the average of all Folds
     print(name, '  Results:= ', cv_results.mean())
# Out:
# D Trees   Results:=  0.7812852022529441
# Gaussian   Results:=  0.7684331797235022
# KNC   Results:=  0.6961597542242702
# Random Forest   Results:=  0.834357398873528
# Gradient Boosting   Results:=  0.8440860215053764
# Linear Disc   Results:=  0.7894777265745008
# Support Machines   Results:=  0.6319252432155659

# %%
#here we import the model then fit our x_train and y_train
from sklearn.ensemble import GradientBoostingClassifier
model=GradientBoostingClassifier()
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predictions=model.predict(x_test)#here we are dealing with x_test
print('the x_train predicted:', predictions)
print('the y train predicted', y_test)
# Out:
# the x_train predicted: ['Not Survived' 'Survived' 'Survived' 'Not Survived' 'Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Survived' 'Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Not Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Not Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Survived' 'Not Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Not Survived' 'Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Survived' 'Not Survived'
#  'Not Survived' 'Not Survived' 'Survived' 'Survived' 'Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Not Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Not Survived' 'Survived'
#  'Not Survived' 'Not Survived' 'Survived' 'Survived' 'Survived'
#  'Not Survived' 'Not Survived' 'Survived' 'Survived' 'Not Survived'
#  'Not Survived' 'Not Survived' 'Not Survived' 'Survived' 'Survived'
#  'Survived' 'Not Survived' 'Survived' 'Not Survived' 'Not Survived'
# ...

# %%
from sklearn.metrics import accuracy_score
print('the accuracy for our model is', accuracy_score(y_test, predictions))
# Out:
# the accuracy for our model is 0.8089887640449438
